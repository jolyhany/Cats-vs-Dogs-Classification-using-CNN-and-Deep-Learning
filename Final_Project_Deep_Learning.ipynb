# %% [markdown]
# # *Import Libraries*

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    Dropout,
    BatchNormalization
)

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import zipfile
from google.colab import drive

# %% [markdown]
# # *Dataset Path*

# %%
# *** Step 1: Mount Drive and Extract Road Damage Dataset
from google.colab import drive
import zipfile
import os

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define paths
zip_path = '/content/drive/MyDrive/DEEP LEARNING /dataset.zip'
extract_path = '/content/drive/MyDrive/DEEP LEARNING'

# Extract the dataset
if not os.path.exists(extract_path):
    os.makedirs(extract_path)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Extraction complete! Folder content:")
print(os.listdir(extract_path))
# Out:
# ✅ Extraction complete! Folder content:
# ['README.dataset.txt', 'README.roboflow.txt', 'test', 'train', 'valid']

# %% [markdown]
# #*Load Dataset*

# %%
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
import torch , torchvision
from torch.utils.data import Subset


train_full = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_full = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

train_idx = []
for i ,(image ,y) in enumerate(train_full):
  if y == 3 or y == 5:
    train_idx.append(i)

text_idx = []
for i ,(image ,y) in enumerate(test_full):
  if y == 3 or y == 5:
    text_idx.append(i)

train_subset = Subset(train_full, train_idx)
test_subset = Subset(test_full, text_idx)

# %%
import torch , torchvision
from torch.utils.data import DataLoader ,  Subset


def collate_fn(batch):
  imgs , labels = [],[]
  for imgs , labels in batch:
    imgs.append(img)
    labels.append(0 if label==3 else 1)
  return torch.stack(imgs) , torch.tensor(labels)

train_loader = DataLoader(train_subset , batch_size=64 , shuffle=True , collate_fn=collate_fn)
test_loader = DataLoader(test_subset , batch_size=64 , shuffle=False , collate_fn=collate_fn)


print("Train size:", len(train_subset))
print("Test size:" ,len(test_subset))
# Out:
# Train size: 10000
# Test size: 2000

# %%
#show samples

import random

classses = ['cat' , 'dog']
plt.figure(figsize=(10,4))
for i in range(10):
  img , label = random.choice(train_subset)
  label = 0 if label==3 else 1
  plt.subplot(2,5,i+1)
  plt.imshow(img.permute(1,2,0)*0.5+0.5)
  plt.title(classses[label])
  plt.axis('off')
plt.show()

# %% [markdown]
# # *Data Preprocessing*
# Image Preprocessing + Data Augmentation

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

valid_datagen = ImageDataGenerator(
    rescale=1./255
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_path = os.path.join(extract_path, "train")
valid_path = os.path.join(extract_path, "valid")
test_path = os.path.join(extract_path, "test")

train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)

valid_data = valid_datagen.flow_from_directory(
    valid_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)

test_data = test_datagen.flow_from_directory(
    test_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 6925 images belonging to 2 classes.
# Found 989 images belonging to 2 classes.
# Found 1977 images belonging to 2 classes.

# %% [markdown]
# # *Build CNN Model*

# %%
model = Sequential()

# Input Layer for explicit input shape definition
model.add(Input(shape=(128,128,3)))

# First Convolution Layer
model.add(Conv2D(
    32,
    (3,3),
    activation='relu'
))

model.add(MaxPooling2D(pool_size=(2,2)))

# Second Convolution Layer
model.add(Conv2D(
    64,
    (3,3),
    activation='relu'
))

model.add(MaxPooling2D(pool_size=(2,2)))

# Batch Normalization
model.add(BatchNormalization())

# Flatten Layer
model.add(Flatten())

# Fully Connected Layer
model.add(Dense(128, activation='relu'))

# Dropout
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# # *Experiment 1 → Adam*

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#train Model

history = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=30
)
# Out:
# Epoch 1/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 120s 399ms/step - accuracy: 0.5281 - loss: 0.8599 - val_accuracy: 0.5035 - val_loss: 0.6927
# Epoch 2/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 79s 363ms/step - accuracy: 0.5574 - loss: 0.6866 - val_accuracy: 0.5086 - val_loss: 0.6871
# Epoch 3/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 77s 355ms/step - accuracy: 0.5523 - loss: 0.6860 - val_accuracy: 0.5642 - val_loss: 0.6790
# Epoch 4/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━
30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7899 - loss: 0.4501 - val_accuracy: 0.7654 - val_loss: 0.5180
# Epoch 29/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 321ms/step - accuracy: 0.7951 - loss: 0.4405 - val_accuracy: 0.7503 - val_loss: 0.5243
# Epoch 30/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.8000 - loss: 0.4408 - val_accuracy: 0.7583 - val_loss: 0.5579

# %%
#Evaluate Model
test_loss, test_accuracy = model.evaluate(test_data)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.7921 - loss: 0.4789
# Test Loss: 0.4789072275161743
# Test Accuracy: 0.7921092510223389

# %%
#Accuracy Visualization
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend(['Train', 'Validation'])

plt.show()

# %%
#Loss Visualization
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(['Train', 'Validation'])

plt.show()

# %% [markdown]
# # *Experiment 2 → SGD*

# %%
model2 = Sequential()

# Input Layer for explicit input shape definition
model2.add(Input(shape=(128,128,3)))

model2.add(Conv2D(
    32,
    (3,3),
    activation='relu'
))

model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(
    64,
    (3,3),
    activation='relu'
))

model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(Flatten())

model2.add(Dense(128, activation='relu'))

model2.add(Dropout(0.3))

model2.add(Dense(1, activation='sigmoid'))

# %%
model2.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#train Model

history2 = model2.fit(
    train_data,
    validation_data=valid_data,
    epochs=30
)
# Out:
# Epoch 1/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 72s 321ms/step - accuracy: 0.5441 - loss: 0.6878 - val_accuracy: 0.5905 - val_loss: 0.6806
# Epoch 2/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 312ms/step - accuracy: 0.5672 - loss: 0.6789 - val_accuracy: 0.5167 - val_loss: 0.6971
# Epoch 3/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 321ms/step - accuracy: 0.5860 - loss: 0.6712 - val_accuracy: 0.5996 - val_loss: 0.6670
# Epoch 4/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.6022 - loss: 0.6643 - val_accuracy: 0.6138 - val_loss: 0.6494
# Epoch 5/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 73s 339ms/step - accuracy: 0.6121 - loss: 0.6558 - val_accuracy: 0.6208 - val_loss: 0.6436
# Epoch 6/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 313ms/step - accuracy: 0.6182 - loss: 0.6504 - val_accuracy: 0.5763 - val_loss: 0.6773
# Epoch 7/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.6277 - loss: 0.6449 - val_accuracy: 0.6734 - val_loss: 0.6250
# Epoch 8/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 315ms/step - accuracy: 0.6351 - loss: 0.6399 - val_accuracy: 0.6491 - val_loss: 0.6208
# Epoch 9/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 315ms/step - accuracy: 0.6482 - loss: 0.6303 - val_accuracy: 0.6704 - val_loss: 0.6148
# Epoch 10/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 314ms/step - accuracy: 0.6543 - loss: 0.6245 - val_accuracy: 0.6714 - val_loss: 0.6097
# Epoch 11/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 320ms/step - accuracy: 0.6585 - loss: 0.6163 - val_accuracy: 0.6390 - val_loss: 0.6215
# Epoch 12/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 324ms/step - accuracy: 0.6771 - loss: 0.6050 - val_accuracy: 0.6835 - val_loss: 0.5902
# Epoch 13/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 71s 327ms/step - accuracy: 0.6833 - loss: 0.5982 - val_accuracy: 0.7139 - val_loss: 0.5845
# Epoch 14/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 325ms/step - accuracy: 0.6882 - loss: 0.5887 - val_accuracy: 0.7118 - val_loss: 0.5747
# Epoch 15/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 323ms/step - accuracy: 0.6956 - loss: 0.5827 - val_accuracy: 0.7078 - val_loss: 0.5671
# Epoch 16/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 73s 339ms/step - accuracy: 0.7028 - loss: 0.5763 - val_accuracy: 0.7230 - val_loss: 0.5576
# Epoch 17/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 319ms/step - accuracy: 0.6979 - loss: 0.5704 - val_accuracy: 0.7139 - val_loss: 0.5592
# Epoch 18/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 315ms/step - accuracy: 0.7089 - loss: 0.5642 - val_accuracy: 0.7371 - val_loss: 0.5431
# Epoch 19/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 67s 311ms/step - accuracy: 0.7220 - loss: 0.5538 - val_accuracy: 0.7159 - val_loss: 0.5513
# Epoch 20/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.7212 - loss: 0.5470 - val_accuracy: 0.7361 - val_loss: 0.5296
# Epoch 21/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 70s 321ms/step - accuracy: 0.7297 - loss: 0.5400 - val_accuracy: 0.7371 - val_loss: 0.5243
# Epoch 22/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 315ms/step - accuracy: 0.7285 - loss: 0.5372 - val_accuracy: 0.7209 - val_loss: 0.5481
# Epoch 23/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.7372 - loss: 0.5308 - val_accuracy: 0.7412 - val_loss: 0.5224
# Epoch 24/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 67s 310ms/step - accuracy: 0.7366 - loss: 0.5270 - val_accuracy: 0.7108 - val_loss: 0.5467
# Epoch 25/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 314ms/step - accuracy: 0.7406 - loss: 0.5236 - val_accuracy: 0.7442 - val_loss: 0.5149
# Epoch 26/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 315ms/step - accuracy: 0.7457 - loss: 0.5138 - val_accuracy: 0.7594 - val_loss: 0.5044
# Epoch 27/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 320ms/step - accuracy: 0.7421 - loss: 0.5153 - val_accuracy: 0.7594 - val_loss: 0.5075
# Epoch 28/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 312ms/step - accuracy: 0.7519 - loss: 0.5049 - val_accuracy: 0.7624 - val_loss: 0.4939
# Epoch 29/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 68s 311ms/step - accuracy: 0.7518 - loss: 0.5042 - val_accuracy: 0.7553 - val_loss: 0.4954
# Epoch 30/30
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 69s 316ms/step - accuracy: 0.7601 - loss: 0.4983 - val_accuracy: 0.7674 - val_loss: 0.4929

# %%
#Evaluate Model
test_loss2, test_accuracy2 = model2.evaluate(test_data)

print("Test Loss:", test_loss2)
print("Test Accuracy:", test_accuracy2)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - accuracy: 0.7643 - loss: 0.4856
# Test Loss: 0.48564282059669495
# Test Accuracy: 0.7642893195152283

# %% [markdown]
# # *Comparison Table*

# %%
print("Experiment 1 (Adam)")
print("Accuracy:", test_accuracy)
print("Loss:", test_loss)

print("-------------------")

print("Experiment 2 (SGD)")
print("Accuracy:", test_accuracy2)
print("Loss:", test_loss2)
# Out:
# Experiment 1 (Adam)
# Accuracy: 0.7921092510223389
# Loss: 0.4789072275161743
# -------------------
# Experiment 2 (SGD)
# Accuracy: 0.7642893195152283
# Loss: 0.48564282059669495

# %% [markdown]
# # *Save Model*

# %%
model.save("cats_vs_dogs_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # *Results*

# %%
results = pd.DataFrame({
    'Model': ['Adam', 'SGD'],
    'Accuracy': [test_accuracy, test_accuracy2],
    'Loss': [test_loss, test_loss2]
})

print(results)
# Out:
#   Model  Accuracy      Loss
# 0  Adam  0.792109  0.478907
# 1   SGD  0.764289  0.485643

# %% [markdown]
# # *Model Summary*

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,177,861 (84.60 MB)
#  Trainable params: 7,392,577 (28.20 MB)
#  Non-trainable params: 128 (512.00 B)
#  Optimizer params: 14,785,156 (56.40 MB)
